# %% [markdown]
# # JPEG image loading and handling

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# print(img.shape)
# plt.imshow(img)  #red, green, blue

# %%
img = mpimg.imread('new.jpg')  #laod image
print(img.shape)
plt.imshow(img)
# Out:
# (891, 693, 3)

# %%
img[:,:,0] #slice only R Cha
# Out:
# array([[228, 228, 228, ..., 229, 229, 229],
#        [228, 228, 228, ..., 229, 229, 229],
#        [228, 228, 228, ..., 229, 229, 229],
#        ...,
#        [ 13,  12,  11, ...,  15,  16,  16],
#        [ 13,  12,  12, ...,  15,  15,  15],
#        [ 14,  13,  12, ...,  15,  15,  14]], dtype=uint8)

# %% [markdown]
# # Read PNG image format

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread('girl.png',format='png')  #laod image
print(img.shape)
plt.imshow(img)
# Out:
# (550, 920, 4)

# %%
#image with photo viewer application 

from PIL import Image

img = Image.open('girl.png')
img.show()

# %% [markdown]
# # Working with OpenCV

# %%
pip install opencv-python#from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

image = cv2.imread('new.jpg') #GBR<-RGB
plt.imshow(img)
plt.show()

# %%
#import cv2

image = cv2.imread('new.jpg')  
plt.imshow(img)
plt.show()

# %%
from PIL import Image 

image = Image.open('new.jpg')
img.show()

# %% [markdown]
# # Handle data with tensorflow from any folder directroy for training purpose

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

training_datagen = ImageDataGenerator(rescale=1.0/255)
training_dir = 'training' #folder path 


#now loading or generate tensor or numpy array from folder 
train_generator = training_datagen.flow_from_directory(
    training_dir,
    target_size=(150,150),
    batch_size=16,
    class_mode='binary')
# Out:
# Found 4 images belonging to 2 classes.

# %% [markdown]
# # load and display image with tensorflow

# %%
from tensorflow.keras.preprocessing import image

X_test=image.load_img('new.jpg',target_size=(75,75),color_mode="rgb"); #loading image and then convert it into grayscale and with it's target size 
X_test=image.img_to_array(X_test); #convert image into array
print(X_test.shape)
plt.imshow(X_test/255)
# Out:
# (75, 75, 3)

# %%
import matplotlib.pyplot as plt

plt.imshow(im, cmap=plt.get_cmap('gray'))

# %% [markdown]
# # load image with numpy

# %%
import numpy as np
im = np.array(Image.open('new.jpg').convert('L'))
plt.imshow(im)
plt.show()

# %% [markdown]
# # Working with Audio Data

# %%
from scipy.io import wavfile
rate1, dat1 =wavfile.read('audio.mp3')
print(rate1)
print(dat1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9852\2621309170.py in <module>
#       1 from scipy.io import wavfile
# ----> 2 rate1, dat1 =wavfile.read('audio.mp3')
#       3 print(rate1)
#       4 print(dat1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\io\wavfile.py in read(filename, mmap)
#     648
#     649     try:
# --> 650         file_size, is_big_endian = _read_riff_chunk(fid)
#     651         fmt_chunk_received = False
#     652         data_chunk_received = False
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\io\wavfile.py in _read_riff_chunk(fid)
#     519     else:
#     520         # There are also .wav files with "FFIR" or "XFIR" signatures?
# --> 521         raise ValueError(f"File format {repr(str1)} not understood. Only "
#     522                          "'RIFF' and 'RIFX' supported.")
#     523
#
# ...
